# %%
from os import listdir
from os.path import isfile, join
from random import shuffle
from scipy import misc
from matplotlib import pyplot as plt
import shutil
# %matplotlib inline

# %%
images_path = './images/'

# %%
onlyfiles = [f for f in listdir(images_path) if isfile(join(images_path, f))]
shuffle(onlyfiles)
file_name = onlyfiles[0]

# %%
img_path = join(images_path, file_name)
print(img_path)
# Out:
# ./images/im_38000_6_28672.png

# %%
img = misc.imread(img_path)

# %%
plt.imshow(img)

# %%
class_dict = {
                0:'bus',
                1:'car',
                2:'moto',
                3:'truck'
             }

# %%
folder_dict = {}

# %%
for i in class_dict:
    folder_dict[class_dict[i]] = join('./', class_dict[i])

# %%
for i in class_dict:
    print('%s\t%s' % (i, class_dict[i]))
# Out:
# 0	bus
# 1	car
# 2	moto
# 3	truck

# %%
classification = 1

# %%
shutil.copyfile(img_path, join(folder_dict[class_dict[classification]], file_name))
# Out:
# './car/im_38000_6_28672.png'
